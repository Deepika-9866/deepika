# %%
print("hello world")
# Out:
# hello world

# %%
list [10,20,30,40,50]
print ("list")
# Out:
# list

# %%
list
# Out:
# list

# %%
list = [10,20,30,40,50,60,70,80]
list
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
list[2]
# Out:
# 30

# %%
x=5
x
# Out:
# 5

# %%
y=2
x+y
# Out:
# 7

# %%
variable
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 variable
#       2 x
#
# NameError: name 'variable' is not defined

# %%
len[list]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 len[list]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
names = ['gf','sgd','gj','gv']
names
names
# Out:
# ['gf', 'sgd', 'gj', 'gv']

# %%
names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 names
#
# NameError: name 'names' is not defined

# %%
names[2]
# Out:
# 'gj'

# %%
namesinsert[2:yy]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 namesinsert[2:yy]
#
# NameError: name 'namesinsert' is not defined

# %%
names[3]
# Out:
# 'gv'
